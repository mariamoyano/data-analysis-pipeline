# %%
import pandas as pd
import numpy as np
import re
import json
from funtions import *

# %%
#Se lee el fichero csv
df = pd.read_csv("../../master.csv", encoding='latin-1')

# %%
print(df.shape)
# Out:
# (27820, 12)

# %%
df.columns
# Out:
# Index(['ï»¿country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
df.rename(columns={'ï»¿country':'Country','HDI for year':'HDI_for_year',' gdp_for_year ($) ':'gdp_for_year','gdp_per_capita ($)':'gdp_per_capita'},inplace=True)

# %%
df.columns
# Out:
# Index(['Country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI_for_year', 'gdp_for_year',
#        'gdp_per_capita', 'generation'],
#       dtype='object')

# %%
df
# Out:
#           Country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI_for_year    gdp_for_year  \
# ...

# %%
df= df.drop_duplicates()
#Vemos que únicamente hay nulos en a columna de HDI
df.isnull().sum()
# Out:
# Country                  0
# year                     0
# sex                      0
# age                      0
# suicides_no              0
# population               0
# suicides/100k pop        0
# country-year             0
# HDI_for_year         19456
# gdp_for_year             0
# gdp_per_capita           0
# generation               0
# dtype: int64

# %%
#list(df["country-year"].value_counts().items())

# %%
df= df[['Country', 'year', 'sex', 'age', 'suicides_no', 'population','suicides/100k pop', 'gdp_for_year','gdp_per_capita', 'generation']]

# %%
df["Country"].value_counts()
# Out:
# Austria                   382
# Netherlands               382
# Iceland                   382
# Mauritius                 382
# Colombia                  372
#                          ...
# Bosnia and Herzegovina     24
# Macau                      12
# Cabo Verde                 12
# Dominica                   12
# Mongolia                   10
# Name: Country, Length: 101, dtype: int64

# %%
print("Min :",min(df["year"]) )
print("Max :",max(df["year"]) )
# Out:
# Min : 1985
# Max : 2016

# %%
df["sex"].value_counts()
# Out:
# female    13910
# male      13910
# Name: sex, dtype: int64

# %%
df["generation"].value_counts()
# Out:
# Generation X       6408
# Silent             6364
# Millenials         5844
# Boomers            4990
# G.I. Generation    2744
# Generation Z       1470
# Name: generation, dtype: int64

# %%
df["age"].value_counts()
# Out:
# 75+ years      4642
# 15-24 years    4642
# 25-34 years    4642
# 55-74 years    4642
# 35-54 years    4642
# 5-14 years     4610
# Name: age, dtype: int64

# %%
#by_year = df.sort_values('gdp_per_capita',ascending = False)
#by_year

# %%
df["gdp_per_capita"]= df["gdp_per_capita"]*0.92
dfgY = dfToEur(df)
df['gdp_for_year'] = dfgY

# %% [markdown]
# La api a la que llamo puede cambiar entre muchos tipos de llamada.Para simplificar cambiare a las monedas principales

# %%
df["gdp_per_capitaEUR"] = change(df["gdp_per_capita"],"EUR")
df["gdp_per_capitaUSD"] = change(df["gdp_per_capita"],"USD")
df["gdp_per_capitaGBP"] = change(df["gdp_per_capita"],"GBP")
df["gdp_per_capitaJPY"] = change(df["gdp_per_capita"],"JPY")
df["gdp_per_capitaBTC"] = change(df["gdp_per_capita"],"BTC")
df["gdp_per_capitaCHF"] = change(df["gdp_per_capita"],"CHF")
df["gdp_for_yearEUR"] = change(df["gdp_for_year"],"EUR")
df["gdp_for_yearUSD"] = change(df["gdp_for_year"],"USD")
df["gdp_for_yearGBP"] = change(df["gdp_for_year"],"GBP")
df["gdp_for_yearJPY"] = change(df["gdp_for_year"],"JPY")
df["gdp_for_yearBTC"] = change(df["gdp_for_year"],"BTC")
df["gdp_for_yearCHF"] = change(df["gdp_for_year"],"CHF")
# Out:
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>
# APIKEY FOUND!!
# <Response [200]>

# %%
df.columns
# Out:
# Index(['Country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'gdp_for_year', 'gdp_per_capita', 'generation',
#        'gdp_per_capitaEUR', 'gdp_per_capitaUSD', 'gdp_per_capitaGBP',
#        'gdp_per_capitaJPY', 'gdp_per_capitaBTC', 'gdp_per_capitaCHF',
#        'gdp_for_yearEUR', 'gdp_for_yearUSD', 'gdp_for_yearGBP',
#        'gdp_for_yearJPY', 'gdp_for_yearBTC', 'gdp_for_yearCHF'],
#       dtype='object')

# %%
df_analysis= df[['Country', 'year', 'sex', 'age', 'suicides_no', 'population',
       'suicides/100k pop', 'generation',
       'gdp_per_capitaEUR', 'gdp_per_capitaUSD', 'gdp_per_capitaGBP',
       'gdp_per_capitaJPY', 'gdp_per_capitaBTC', 'gdp_per_capitaCHF',
       'gdp_for_yearEUR', 'gdp_for_yearUSD', 'gdp_for_yearGBP',
       'gdp_for_yearJPY', 'gdp_for_yearBTC', 'gdp_for_yearCHF']]

# %%
df_analysis
# Out:
#           Country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop       generation  gdp_per_capitaEUR  \
# 0                   6.71     Generation X             732.32
# ...

# %%
# GUARDAR EL CSV LIMPIO
df_analysis.to_csv("../OUTPUT/analysis.csv")
